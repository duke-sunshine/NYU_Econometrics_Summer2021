# %% [markdown]
# <a href="https://colab.research.google.com/github/duke-sunshine/NYU_Econometrics_Summer2021/blob/main/Econometrics_Milestone2_Panel_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Preparation

# %% [markdown]
# [Data Metrics](https://github.com/coinmetrics-io/data/blob/master/csv/metrics.csv)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### import the data for Ethereum

# %%
df_eth=pd.read_csv("https://raw.githubusercontent.com/coinmetrics-io/data/master/csv/eth.csv")
df_eth.head()
# Out:
#          time  AdrActCnt  ...  VtyDayRet180d  VtyDayRet30d
# 0  2015-07-30     9206.0  ...            NaN           NaN
# 1  2015-07-31      424.0  ...            NaN           NaN
# 2  2015-08-01      413.0  ...            NaN           NaN
# 3  2015-08-02      432.0  ...            NaN           NaN
# 4  2015-08-03      444.0  ...            NaN           NaN
#
# [5 rows x 139 columns]

# %%
df_eth['Type'] = 'eth'
df_eth.head()
# Out:
#          time  AdrActCnt  AdrBal1in100KCnt  ...  VtyDayRet180d  VtyDayRet30d  Type
# 0  2015-07-30     9206.0            5685.0  ...            NaN           NaN   eth
# 1  2015-07-31      424.0            5692.0  ...            NaN           NaN   eth
# 2  2015-08-01      413.0            5699.0  ...            NaN           NaN   eth
# 3  2015-08-02      432.0            5708.0  ...            NaN           NaN   eth
# 4  2015-08-03      444.0            5715.0  ...            NaN           NaN   eth
#
# [5 rows x 140 columns]

# %% [markdown]
# ### Import the Data for Ethereum Classic

# %%
df_etc=pd.read_csv("https://raw.githubusercontent.com/coinmetrics-io/data/master/csv/etc.csv")
df_etc.head()
# Out:
#          time  AdrActCnt  ...  VtyDayRet180d  VtyDayRet30d
# 0  2016-07-20    21680.0  ...            NaN           NaN
# 1  2016-07-21    17037.0  ...            NaN           NaN
# 2  2016-07-22    13208.0  ...            NaN           NaN
# 3  2016-07-23     9838.0  ...            NaN           NaN
# 4  2016-07-24    14910.0  ...            NaN           NaN
#
# [5 rows x 134 columns]

# %%
### change to dateime
df_eth['time']=pd.to_datetime(df_eth['time'])
df_eth.dtypes
# Out:
# time                datetime64[ns]
# AdrActCnt                  float64
# AdrBal1in100KCnt           float64
# AdrBal1in100MCnt           float64
# AdrBal1in10BCnt            float64
#                          ...
# TxTfrValMedUSD             float64
# VelCur1yr                  float64
# VtyDayRet180d              float64
# VtyDayRet30d               float64
# Type                        object
# Length: 140, dtype: object

# %%
df_etc['Type'] = 'etc'
df_etc.head()
# Out:
#          time  AdrActCnt  AdrBal1in100KCnt  ...  VtyDayRet180d  VtyDayRet30d  Type
# 0  2016-07-20    21680.0            5491.0  ...            NaN           NaN   etc
# 1  2016-07-21    17037.0            5471.0  ...            NaN           NaN   etc
# 2  2016-07-22    13208.0            5497.0  ...            NaN           NaN   etc
# 3  2016-07-23     9838.0            5499.0  ...            NaN           NaN   etc
# 4  2016-07-24    14910.0            5304.0  ...            NaN           NaN   etc
#
# [5 rows x 135 columns]

# %%
### change to dateime
df_etc['time']=pd.to_datetime(df_etc['time'])
df_etc.dtypes
# Out:
# time                datetime64[ns]
# AdrActCnt                  float64
# AdrBal1in100KCnt           float64
# AdrBal1in100MCnt           float64
# AdrBal1in10BCnt            float64
#                          ...
# TxTfrValMedUSD             float64
# VelCur1yr                  float64
# VtyDayRet180d              float64
# VtyDayRet30d               float64
# Type                        object
# Length: 135, dtype: object

# %%
df =pd.concat([df_eth, df_etc], ignore_index=True)
df.head()
# Out:
#         time  AdrActCnt  AdrBal1in100KCnt  ...  VtyDayRet180d  VtyDayRet30d  Type
# 0 2015-07-30     9206.0            5685.0  ...            NaN           NaN   eth
# 1 2015-07-31      424.0            5692.0  ...            NaN           NaN   eth
# 2 2015-08-01      413.0            5699.0  ...            NaN           NaN   eth
# 3 2015-08-02      432.0            5708.0  ...            NaN           NaN   eth
# 4 2015-08-03      444.0            5715.0  ...            NaN           NaN   eth
#
# [5 rows x 140 columns]

# %%
df.tail()
# Out:
#            time  AdrActCnt  AdrBal1in100KCnt  ...  VtyDayRet180d  VtyDayRet30d  Type
# 3915 2021-06-01    30076.0               NaN  ...       0.098853      0.164976   etc
# 3916 2021-06-02    31725.0               NaN  ...       0.098553      0.163022   etc
# 3917 2021-06-03    31568.0               NaN  ...       0.098549      0.154010   etc
# 3918 2021-06-04    31751.0               NaN  ...       0.098747      0.143614   etc
# 3919 2021-06-05    29345.0               NaN  ...       0.098804      0.126066   etc
#
# [5 rows x 140 columns]

# %%
df=df.dropna()
df.head()
# Out:
#           time  AdrActCnt  AdrBal1in100KCnt  ...  VtyDayRet180d  VtyDayRet30d  Type
# 374 2016-08-07    20085.0            5715.0  ...       0.084586      0.091806   eth
# 375 2016-08-08    20439.0            5738.0  ...       0.084186      0.091690   eth
# 376 2016-08-09    22799.0            5761.0  ...       0.081587      0.092947   eth
# 377 2016-08-10    21183.0            5817.0  ...       0.081409      0.092723   eth
# 378 2016-08-11    22502.0            5842.0  ...       0.081366      0.092968   eth
#
# [5 rows x 140 columns]

# %% [markdown]
# # Dummy Variables

# %% [markdown]
# https://towardsdatascience.com/a-guide-to-panel-data-regression-theoretics-and-implementation-with-python-4c84c5055cf8

# %%
df['eth']=df['Type'].apply(lambda x: 1 if x=='eth' else 0)
df.head()
# Out:
#           time  AdrActCnt  AdrBal1in100KCnt  ...  VtyDayRet30d  Type  eth
# 374 2016-08-07    20085.0            5715.0  ...      0.091806   eth    1
# 375 2016-08-08    20439.0            5738.0  ...      0.091690   eth    1
# 376 2016-08-09    22799.0            5761.0  ...      0.092947   eth    1
# 377 2016-08-10    21183.0            5817.0  ...      0.092723   eth    1
# 378 2016-08-11    22502.0            5842.0  ...      0.092968   eth    1
#
# [5 rows x 141 columns]

# %% [markdown]
# # The Fixed Effect: across sections

# %% [markdown]
# #The Time Effect: across time
